# %% [markdown]
# # Notebook_14 - Visualization with pandas

# %% [markdown]
# Now that we hav sufficient knowledge about matplotlib, let us try to plot the data that is given by pandas DataFrame.

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("../tested.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df = df[df["Fare"] < 500] # exclude fares > 500

# %%
import matplotlib.pyplot as plt
plt.plot(df["Fare"], df["Age"], 'o')
plt.show()

# %% [markdown]
# Also there are pandas functions that allow for plotting.

# %%
plt.bar(df["Pclass"], df["Fare"])
plt.xlabel('Pclass')
plt.ylabel('Fare')
plt.show()

# %%
plt.pie(df.iloc[0:10]["Fare"], labels=df.iloc[0:10]["Fare"])
plt.show()

# %%
plt.plot(df["Age"], linestyle = 'dotted')
plt.show()

# %%
plt.bar(df["Sex"], df["Age"])
plt.xlabel('Sex')
plt.ylabel('Age')
plt.show()

# %%
new_df = df[df["Age"] <= 18]
new_df.head(10)
# Out:
#     PassengerId  Survived  Pclass                                       Name  \
# 5           897         0       3                 Svensson, Mr. Johan Cervin
# 8           900         1       3  Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 21          913         0       3                  Olsen, Master. Artur Karl
# 55          947         0       3                       Rice, Master. Albert
# 60          952         0       3                            Dika, Mr. Mirko
# 62          954         0       3               Bjorklund, Mr. Ernst Herbert
# 64          956         0       1                Ryerson, Master. John Borie
# 66          958         1       3                    Burns, Miss. Mary Delia
# 80          972         0       3                       Boulos, Master. Akar
# 87          979         1       3                 Badman, Miss. Emily Louisa
#
#        Sex   Age  SibSp  Parch     Ticket      Fare            Cabin Embarked
# ...

# %%
plt.bar(new_df["Pclass"], new_df["Fare"])
plt.xlabel('Pclass')
plt.ylabel('Fare')
plt.show()

# %%
plt.plot(new_df["Fare"], new_df["Age"], 'o')
plt.show()

# %%
plt.hist(df["Embarked"], bins=3)
plt.show()

# %% [markdown]
# Now that we have sufficient knowledge about plotting, we can easily manipulate and illustrate data. Note, that these plots are good for in code use, but if you want to put something like that, there are more advanced ways to do it (such as converting animation of a plot from matplotlib to file). If you want to try other plotting libraries:
#
# 1. https://seaborn.pydata.org
# 2. https://plotly.com/python/
# 3. https://ggplot2.tidyverse.org
#
# Additionaly, remember, that pandas dataframe can be converted to almost any file format (as it can be converted to csv), so you can import data from file, manipulate it with pandas and then export back to file.
#
# If you wish, you can plot without pandas, with numpy, or even plot with pure python. Do not forget about users that do not have jupyter, so adjust your code with `print` and `plt.show()`.
#
# In the next notebook the final project will be presented, after all, that is it.

# %% [markdown]
# ## Tasks

# %% [markdown]
# 1. Find any datase on https://www.kaggle.com or somewhere else and create similar plots on data
# 2. Pick any of the additional plotting libraries and try to make some unqiue plots*
# 3. Create data frame filled with random numbers and perform data manipulations on dataset
# 4. Convert any dataframe you want to `.csv` file and convert any file except for `.csv` ones to DataFrame
